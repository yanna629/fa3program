# %% [markdown]
# <a href="https://colab.research.google.com/github/yanna629/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Ask for student's info
name = input("Enter your name: ")
age = input("Enter your age: ")
course = input("Enter your course: ")

# Display formatted output
print("Student Information")
print("Name:", name)
print("Age:", age)
print("Course:", course)
# Out:
# Enter your name: Ana
# Enter your age: 19
# Enter your course: Computer Science
# Student Information
# Name: Ana
# Age: 19
# Course: Computer Science

# %%
score = int(input("Enter your score: "))
# Check if pass or fail
if score >= 75:
  print("Passed")
else:
  print("Failed]")
# Out:
# Enter your score: 76
# Passed

# %%
# Input student info
name = input("Enter student's name: ")
score = int(input("Enter student's score: "))
# Determine letter grade
if score >= 90:
  grade = "A"
elif score >= 80:
  grade = "B"
elif score >= 70:
  grade = "C"
else:
  grade = "F"
# Display result
print("Score:", score)
print("Grade:", grade)
# Out:
# Enter student's name: Yanna
# Enter student's score: 98
# Score: 98
# Grade: A
